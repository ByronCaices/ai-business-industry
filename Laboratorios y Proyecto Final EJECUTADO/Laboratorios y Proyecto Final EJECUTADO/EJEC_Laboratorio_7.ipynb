# %% [markdown]
# # 📗 Laboratorio 7 – Arquitecturas Avanzadas
# **Curso:** IA Aplicada a la Industria
# **Profesora:** Myriam Vera Fuentes
# **Ayudante:** Pablo Macuada Rozas
#
# ---
# En este Laboratorio exploraras y aplicaras arquitecturas avanzadas de redes neuronales para tareas industriales, incluyendo redes profundas y activaciones no lineales.

# %% [markdown]
# ## 🧠 Introducción
#
# A medida que los problemas industriales se vuelven más complejos, es necesario utilizar redes más profundas que puedan capturar relaciones no lineales entre los datos.
#
# En este laboratorio entrenaremos una red neuronal profunda (deep neural network) usando Keras, con múltiples capas ocultas y funciones de activación ReLU.
#
# Aplicaremos esta arquitectura a un caso de predicción industrial (rendimiento de máquinas).

# %%
# Importar librerías necesarias
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'  # suprimir avisos de TensorFlow
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'  # desactivar GPU para evitar mensajes
import numpy as np
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# Simulación de datos de rendimiento industrial
np.random.seed(0)  # semilla para reproducibilidad
X = np.random.rand(1000, 10)  # características simuladas
y = 5*X[:,0] - 3*X[:,1] + 2*X[:,2] + np.random.randn(1000)*0.5  # salida con ruido

# División y normalización de los datos
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# Definir la red neuronal profunda
model = keras.models.Sequential([
    keras.layers.Input(shape=(X_train.shape[1],)),  # capa de entrada
    keras.layers.Dense(64, activation='relu'),  # primera capa oculta
    keras.layers.Dense(64, activation='relu'),  # segunda capa oculta
    keras.layers.Dense(1)  # capa de salida para regresión
])

# Configurar el entrenamiento
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# Entrenar el modelo
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2, verbose=0)

# %%
# Evaluar el modelo con datos de prueba
loss, mae = model.evaluate(X_test, y_test, verbose=0)
print(f"Error absoluto medio (MAE): {mae:.2f}")
# Out:
# Error absoluto medio (MAE): 0.47

# %%
# Graficar la evolución del error durante el entrenamiento
plt.plot(history.history['loss'], label='Pérdida entrenamiento')
plt.plot(history.history['val_loss'], label='Pérdida validación')
plt.xlabel('Épocas')
plt.ylabel('MSE')
plt.legend()
plt.title("Curva de entrenamiento")
plt.grid(True)
plt.show()

# %% [markdown]
# ## 📋 Tarea 7
#
# 1. ¿Cuál es la ventaja de usar capas ReLU en redes profundas?
# A) Hace que el modelo sea lineal
# B) Introduce no linealidad y mejora el aprendizaje
# C) Reduce los datos
# D) Actúa como función de pérdida
#
# 2. ¿Qué significa un MAE bajo?
# A) La red no aprendió
# B) Hay sobreajuste
# C) Las predicciones son cercanas a los valores reales
# D) El error cuadrático es mayor
#
# 3. ¿Por qué es importante normalizar los datos de entrada?
# A) Para eliminar columnas
# B) Para que los pesos iniciales no dominen
# C) Porque mejora la legibilidad
# D) Para codificar variables categóricas
#
# 4. ¿Qué indica una curva de validación que sube mientras la de entrenamiento baja?
# A) Buen ajuste
# B) Datos balanceados
# C) Sobreajuste
# D) Subajuste
#
# 5. ¿Qué capa final se usa para regresión?
# A) softmax
# B) relu
# C) sigmoid
# D) lineal
#
# 6. ¿Qué puede ocurrir si se entrena una red profunda con pocos datos?
# A) Mejor desempeño
# B) Sobreajuste
# C) Subajuste
# D) Mejora de precisión
#
# ✅ Marca las respuestas correctas escribiendo las letras seleccionadas abajo en un cuadro de markdown

# %% [markdown]
# ## 🌟 Actividades Voluntarias ( optativas )
#
# 1. Agrega más capas a la red y observa los efectos sobre el error.
# 2. Cambia la función de activación a `tanh` y evalúa el comportamiento.
# 3. Aplica dropout para reducir el sobreajuste.

# %% [markdown]
# ## ✅ Respuestas
# 1.
# 2.
# 3.
# 4.
# 5.
# 6.
