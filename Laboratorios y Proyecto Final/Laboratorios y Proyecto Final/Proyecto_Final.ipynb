# %% [markdown]
# # 📗 Proyecto Final
# **Curso:** IA Aplicada a la Industria
# **Profesora:** Myriam Vera Fuentes
# **Ayudante:** Pablo Macuada Rozas
#
# ---
# ## 🎯 Objetivo
# Desarrollar un proyecto completo de IA aplicado a un problema industrial, integrando todos los conocimientos previos: desde la preparación de datos hasta la evaluación e interpretación de modelos.

# %% [markdown]
# ## 🧠 Introducción
#
# En este laboratorio integrador, los estudiantes deberán:
#
# - Formular un problema industrial aplicable a IA
# - Simular o utilizar un dataset representativo
# - Proponer, entrenar y evaluar un modelo de ML o DL
# - Interpretar sus resultados con métricas y visualizaciones
# - Considerar aspectos éticos y de responsabilidad

# %% [markdown]
# ## 📦 Estructura del Proyecto
#
# El notebook debe incluir las siguientes secciones:
#
# 1. **Contexto del problema industrial**
#    Breve descripción del problema, sus variables y su importancia.
#
# 2. **Exploración y visualización de datos**
#    Gráficos, estadísticos, correlaciones, análisis inicial.
#
# 3. **Preprocesamiento y selección de variables**
#    Limpieza, codificación, normalización, separación de features y target.
#
# 4. **Entrenamiento del modelo**
#    Algoritmo(s) elegido(s): clasificación, regresión o clustering.
#    Comparación si aplica.
#
# 5. **Evaluación y validación**
#    Métricas relevantes al tipo de modelo y justificación de resultados.
#
# 6. **Interpretabilidad y responsabilidad**
#    Técnicas como LIME/SHAP o análisis de importancia de variables.
#    Identificación de riesgos o sesgos potenciales.
#
# 7. **Conclusiones y recomendaciones**
#    Propuesta de mejora, aplicación real, posibilidad de despliegue.

# %% [markdown]
# ## 🧪 Caso de ejemplo opcional (para quienes no tengan datos)
#
# Simulación de control de calidad en productos industriales:
#
# - Variables: temperatura, vibración, presión, velocidad, operador
# - Objetivo: clasificar productos como aceptables (0) o defectuosos (1)
#
# Este dataset puede generarse usando NumPy si no se cuenta con datos reales.

# %%
# Simulación de datos (puede usarse como base del proyecto)
import numpy as np
import pandas as pd

np.random.seed(42)
n = 600
data = pd.DataFrame({
    'temperatura': np.random.normal(70, 5, n),
    'vibracion': np.random.normal(1.1, 0.2, n),
    'presion': np.random.normal(32, 3, n),
    'velocidad': np.random.normal(45, 8, n),
    'operador': np.random.choice(['A', 'B', 'C'], size=n),
})

# Variable objetivo (calidad)
data['defectuoso'] = ((data['temperatura'] > 73) & (data['presion'] > 34)).astype(int)

data.head()

# %% [markdown]
# ## 📝 Rúbrica Sugerida
#
# | Criterio | Puntos |
# |---------|--------|
# | Definición clara del problema industrial | 10 |
# | Limpieza y análisis de datos | 10 |
# | Correcta implementación del modelo | 20 |
# | Evaluación con métricas y visualizaciones | 20 |
# | Análisis de interpretabilidad y ética | 20 |
# | Conclusiones y recomendaciones | 10 |
# | Calidad general del notebook y justificación | 10 |
#
# **Total: 100 puntos**

# %% [markdown]
# ## 📋 Entregable
#
# Este notebook debe ser completado por cada equipo o estudiante y entregado en la plataforma oficial antes del fin de la Semana 15.
#
# Formato de entrega:
# - Notebook `.ipynb` completo
# - Datos simulados o reales integrados o enlazados
# - Si se usa Google Colab, incluir enlace con permisos

# %% [markdown]
# ## 🌟 Sugerencias y Buenas Prácticas
#
# - Si el modelo es de clasificación, usar `accuracy`, `precision`, `recall`, `f1`
# - Si es de regresión, usar `MAE`, `MSE`, `R²`
# - Visualizar resultados, confusión, correlaciones o decisiones
# - Explicar resultados con gráficos y justificaciones claras
# - Incluir reflexiones sobre impacto social y responsabilidad del modelo
